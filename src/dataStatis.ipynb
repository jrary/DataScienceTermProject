# %%
import pandas as pd
import numpy as np

df = pd.read_csv('assets/output/datasetCombine.csv')

print("combine dataset describe:")
print(df.describe())

print('number of null value:')
print(df.isna().sum())
# Out:
# combine dataset describe:
#        sulfur_dioxide_min  sulfur_dioxide_max  sulfur_dioxide_mean  \
# count         3889.000000         3889.000000          3889.000000
# mean             0.003175            0.006899             0.004596
# std              0.001772            0.004804             0.002757
# min              0.000000            0.001000             0.001000
# 25%              0.002000            0.004000             0.002750
# 50%              0.003000            0.006000             0.003955
# 75%              0.004000            0.009000             0.005542
# max              0.018000            0.070000             0.024458
#
#        sulfur_dioxide_median  carbon_monoxide_min  carbon_monoxide_max  \
# count            3889.000000          3900.000000          3900.000000
# mean                0.004439             0.437077             0.867154
# std                 0.002710             0.174039             0.434332
# min                 0.001000             0.000000             0.100000
# 25%                 0.003000             0.300000             0.600000
# 50%                 0.004000             0.400000             0.700000
# 75%                 0.005000             0.500000             1.000000
# max                 0.024000             2.200000             4.100000
#
#        carbon_monoxide_mean  carbon_monoxide_median    ozone_min    ozone_max  \
# count           3900.000000             3900.000000  3894.000000  3894.000000
# mean               0.612769                0.599154     0.004906     0.043607
# std                0.247412                0.249322     0.007060     0.025449
# min                0.100000                0.100000     0.001000     0.001000
# 25%                0.454167                0.400000     0.002000     0.026000
# 50%                0.558333                0.500000     0.002000     0.039000
# 75%                0.700000                0.700000     0.004000     0.059000
# max                2.291667                2.200000     0.071000     0.176000
#
#        ...  wind speed_median  wind direction_min  wind direction_max  \
# count  ...        3461.000000         3622.000000         3622.000000
# mean   ...           2.009130           75.197129          305.960243
# std    ...           1.022607           84.659663           66.032773
# min    ...           0.500000            0.000000           17.000000
# 25%    ...           1.400000            8.000000          283.000000
# 50%    ...           2.000000           45.000000          324.500000
# 75%    ...           2.300000          119.000000          356.000000
# max    ...          18.799999          316.000000          360.000000
#
#        wind direction_mean  wind direction_median  sky state_min  \
# count          3622.000000            3622.000000    3608.000000
# mean            206.021325             212.886527       1.698448
# std              68.474870              83.648714       0.893545
# min               8.500000               8.500000       1.000000
# 25%             163.444410             143.000000       1.000000
# 50%             213.854730             229.000000       1.000000
# 75%             256.430743             281.000000       2.000000
# max             333.695946             360.000000       4.000000
#
#        sky state_max  sky state_mean  sky state_median      weekday
# count    3608.000000     3608.000000       3608.000000  3951.000000
# mean        3.272173        2.464517          2.451635     3.996457
# std         0.858869        0.918670          1.070474     1.998351
# min         1.000000        1.000000          1.000000     1.000000
# 25%         3.000000        1.662162          1.375000     2.000000
# 50%         3.000000        2.490398          3.000000     4.000000
# 75%         4.000000        3.195946          3.000000     6.000000
# max         4.000000        4.000000          4.000000     7.000000
#
# [8 rows x 53 columns]
# number of null value:
# date                                     0
# sulfur_dioxide_min                      62
# sulfur_dioxide_max                      62
# sulfur_dioxide_mean                     62
# sulfur_dioxide_median                   62
# carbon_monoxide_min                     51
# carbon_monoxide_max                     51
# carbon_monoxide_mean                    51
# carbon_monoxide_median                  51
# ozone_min                               57
# ozone_max                               57
# ozone_mean                              57
# ozone_median                            57
# nitrogen_dioxide_min                    57
# nitrogen_dioxide_max                    57
# nitrogen_dioxide_mean                   57
# nitrogen_dioxide_median                 57
# fine_dust_pm10_min                      74
# fine_dust_pm10_max                      74
# fine_dust_pm10_mean                     74
# fine_dust_pm10_median                   74
# rainfall_min                           980
# rainfall_max                           980
# rainfall_mean                          980
# rainfall_median                        980
# probability of precipitation_min       419
# probability of precipitation_max       419
# probability of precipitation_mean      419
# probability of precipitation_median    419
# humidity_min                           151
# humidity_max                           151
# humidity_mean                          151
# humidity_median                        151
# highest temperature_min                120
# highest temperature_max                120
# highest temperature_mean               120
# highest temperature_median             120
# lowest temperature_min                 123
# lowest temperature_max                 123
# lowest temperature_mean                123
# lowest temperature_median              123
# wind speed_min                         490
# wind speed_max                         490
# wind speed_mean                        490
# wind speed_median                      490
# wind direction_min                     329
# wind direction_max                     329
# wind direction_mean                    329
# wind direction_median                  329
# sky state_min                          343
# sky state_max                          343
# sky state_mean                         343
# sky state_median                       343
# weekday                                  0
# visitor                                  0
# dtype: int64
