# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/atmosphere.csv')

plt.figure(figsize=(20,5))
plt.title("sulfur dioxide")
plt.plot(df['sulfur_dioxide_min'],label = 'sulfur_dioxide_min')
plt.plot(df['sulfur_dioxide_max'],label ='sulfur_dioxide_max')
plt.plot(df['sulfur_dioxide_mean'],label ='sulfur_dioxide_mean')
plt.plot(df['sulfur_dioxide_median'],label ='sulfur_dioxide_median')
#plt.plot(df['sulfur_dioxide_std'],label ='sulfur_dioxide_std')

plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/atmosphere.csv')

plt.figure(figsize=(15,5))
plt.title("carbon monoxide")
plt.plot(df["carbon_monoxide_max"],label="carbon_monoxide_max") 
plt.plot(df["carbon_monoxide_min"],label="carbon_monoxide_min") 
plt.plot(df["carbon_monoxide_mean"],label="carbon_monoxide_mean") 
plt.plot(df["carbon_monoxide_median"],label="carbon_monoxide_median") 
#plt.plot(df["carbon_monoxide_std"],label="carbon_monoxide_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/atmosphere.csv')

plt.figure(figsize=(15,5))
plt.title("ozone")
plt.plot(df["ozone_max"],label="ozone_max") 
plt.plot(df["ozone_min"],label="ozone_min") 
plt.plot(df["ozone_mean"],label="ozone_mean") 
plt.plot(df["ozone_median"],label="ozone_median") 
#plt.plot(df["ozone_std"],label="ozone_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/atmosphere.csv')

plt.figure(figsize=(15,5))
plt.title("nitrogen dioxide")
plt.plot(df["nitrogen_dioxide_max"],label="nitrogen_dioxide_max") 
plt.plot(df["nitrogen_dioxide_min"],label="nitrogen_dioxide_min") 
plt.plot(df["nitrogen_dioxide_mean"],label="nitrogen_dioxide_mean") 
plt.plot(df["nitrogen_dioxide_median"],label="nitrogen_dioxide_median") 
#plt.plot(df["nitrogen_dioxide_std"],label="nitrogen_dioxide_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/atmosphere.csv')

plt.figure(figsize=(15,5))
plt.title("fine dust pm10")
plt.plot(df["fine_dust_pm10_max"],label="fine_dust_pm10_max") 
plt.plot(df["fine_dust_pm10_min"],label="fine_dust_pm10_min") 
plt.plot(df["fine_dust_pm10_mean"],label="fine_dust_pm10_mean") 
plt.plot(df["fine_dust_pm10_median"],label="fine_dust_pm10_median") 
#plt.plot(df["fine_dust_pm10_std"],label="fine_dust_pm10_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/부림동_6시간강수량.csv')

plt.figure(figsize=(15,5))
plt.title("rainfall")
plt.plot(df["rainfall_max"],label="rainfall_max") 
plt.plot(df["rainfall_min"],label="rainfall_min") 
plt.plot(df["rainfall_mean"],label="rainfall_mean") 
plt.plot(df["rainfall_median"],label="rainfall_median") 
#plt.plot(df["rainfall_std"],label="rainfall_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/부림동_강수확률.csv')

plt.figure(figsize=(15,5))
plt.title("probability of precipitation")
plt.plot(df["probability of precipitation_max"],label="probability_of_precipitation_max") 
plt.plot(df["probability of precipitation_min"],label="probability_of_precipitation_min") 
plt.plot(df["probability of precipitation_mean"],label="probability_of_precipitation_mean") 
plt.plot(df["probability of precipitation_median"],label="probability_of_precipitation_median") 
#plt.plot(df["probability of precipitation_std"],label="probability_of_precipitation_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/부림동_습도.csv')

plt.figure(figsize=(20,5))
plt.title("humidity")
plt.plot(df["humidity_max"],label="humidity_max") 
plt.plot(df["humidity_min"],label="humidity_min") 
plt.plot(df["humidity_mean"],label="humidity_mean") 
plt.plot(df["humidity_median"],label="humidity_median") 
#plt.plot(df["humidity_std"],label="humidity_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/부림동_일최고기온.csv')

plt.figure(figsize=(15,5))
plt.title("highest temperature")
plt.plot(df["highest temperature_max"],label="highest_temperature_max") 
plt.plot(df["highest temperature_min"],label="highest_temperature_min") 
plt.plot(df["highest temperature_mean"],label="highest_temperature_mean") 
plt.plot(df["highest temperature_median"],label="highest_temperature_median") 
#plt.plot(df["highest temperature_std"],label="highest_temperature_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/부림동_일최저기온.csv')

plt.figure(figsize=(15,5))
plt.title("lowest temperature")
plt.plot(df["lowest temperature_max"],label="lowest_temperature_max") 
plt.plot(df["lowest temperature_min"],label="lowest_temperature_min") 
plt.plot(df["lowest temperature_mean"],label="lowest_temperature_mean") 
plt.plot(df["lowest temperature_median"],label="lowest_temperature_median") 
#plt.plot(df["lowest temperature_std"],label="lowtest_temperature_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/부림동_풍속.csv')

plt.figure(figsize=(15,5))
plt.title("wind speed")
plt.plot(df["wind speed_max"],label="wind_speed_max") 
plt.plot(df["wind speed_min"],label="wind_speed_min") 
plt.plot(df["wind speed_mean"],label="wind_speed_mean") 
plt.plot(df["wind speed_median"],label="wind_speed_median") 
#plt.plot(df["wind speed_std"],label="wind_speed_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/부림동_풍향.csv')

plt.figure(figsize=(15,5))
plt.title("wind direction")
plt.plot(df["wind direction_max"],label="wind_direction_max") 
plt.plot(df["wind direction_min"],label="wind_direction_min") 
plt.plot(df["wind direction_mean"],label="wind_direction_mean") 
plt.plot(df["wind direction_median"],label="wind_direction_median") 
#plt.plot(df["wind direction_std"],label="wind_direction_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('./assets/output/부림동_하늘상태.csv')

plt.figure(figsize=(15,5))
plt.title("sky state")
plt.plot(df["sky state_max"],label="sky_state_max") 
plt.plot(df["sky state_min"],label="sky_state_min") 
plt.plot(df["sky state_mean"],label="sky_state_mean") 
plt.plot(df["sky state_median"],label="sky_state_median") 
#plt.plot(df["sky state_std"],label="sky_state_std") 
plt.legend()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2008')]

print(df)

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2009')]

print(df)

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2010')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2011')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2012')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2013')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2014')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2015')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2016')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2017')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2018')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2019')]

print(df)

plt.figure(figsize=(20,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2020')]

print(df)

plt.figure(figsize=(40,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(df['date'],df['visitor'])

# %%
#20000이하의 값
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
fil_df = df[df['visitor'] <= 20000]
print(fil_df)

# %%
#여기서부터 년도별, 20000만 이하의 방문객
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2008')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])
# Out:
# <BarContainer object of 75 artists>

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2009')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2010')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2011')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2012')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2013')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2014')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2015')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])
# Out:
# <BarContainer object of 306 artists>

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2016')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2017')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2018')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2019')]
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['date'] = df['date'].astype(str)
df = df[df['date'].str.startswith('2020')]
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])

# %%
df = pd.read_csv('./assets/output/visitors.csv')
df['date'] = df['date'].astype(str)

df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
fil_df = df[df['visitor'] <= 20000]

plt.figure(figsize=(100,5))
plt.title("Visitors")
plt.xlabel("date")
plt.ylabel("visitors")

plt.bar(fil_df['date'],fil_df['visitor'])
# Out:
# <BarContainer object of 3428 artists>

# %%
df['visitor'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
fil_df['visitor'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['visitor'].describe()
# Out:
# count      3951.000000
# mean       9122.186029
# std       11653.034037
# min           2.000000
# 25%        1840.000000
# 50%        4619.000000
# 75%       11280.500000
# max      115002.000000
# Name: visitor, dtype: float64

# %%
fil_df['visitor'].describe()
# Out:
# count     3428.000000
# mean      5332.790257
# std       4800.091169
# min          2.000000
# 25%       1631.500000
# 50%       3634.000000
# 75%       7537.250000
# max      19982.000000
# Name: visitor, dtype: float64

# %%
#히스토그램
#전체 데이터
df = pd.read_csv('./assets/output/visitors.csv')
df['date'] = df['date'].astype(str)
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['visitor'].plot(kind='hist',bins=range(0,100001,100))
# Out:
# <Axes: ylabel='Frequency'>

# %%
#히스토그램
#방문객 20000만이하의 데이터 범위설정
fil_df = df[df['visitor'] <= 20000]
fil_df['visitor'].plot(kind='hist',bins=range(0,20001,100))
# Out:
# <Axes: ylabel='Frequency'>

# %%
#산점도
#x축 - 방문자수 ,y축 - 데이터개수
plt.scatter(fil_df['visitor'], range(len(fil_df['visitor'])))

# %%
#이상치 찾기 - Turkey Fences
import numpy as np
import matplotlib.pyplot
df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)
df = df[df['visitor'] <= 20000]

def find_outlier_Turkey(data):
    q1, q3 = np.percentile(data,[25,75])

    iqr = q3 - q1
    
    lower_bound = q1 - (iqr*1.5)
    upper_bound = q3 + (iqr*1.5)

    mask = np.where((data>upper_bound)|(data<lower_bound))

    return mask

outliers =find_outlier_Turkey(df['visitor'])[0]
print(len(outliers))
outliers
# Out:
# 365
# array([   2,    3,    4,   10,   11,   17,   18,   25,   31,   32,   38,
#          39,   92,   93,   96,   99,  100,  106,  107,  111,  112,  113,
#         120,  121,  151,  158,  171,  178,  179,  185,  186,  189,  192,
#         193,  199,  200,  212,  213,  214,  215,  216,  220,  221,  228,
#         234,  235,  241,  242,  248,  255,  256,  263,  347,  353,  354,
#         360,  367,  368,  369,  374,  375,  382,  388,  389,  514,  515,
#         529,  543,  549,  550,  556,  557,  563,  564,  570,  571,  577,
#         578,  581,  584,  585,  591,  592,  596,  597,  598,  605,  606,
#         609,  612,  613,  722,  723,  724,  725,  737,  738,  739,  745,
#         746,  751,  752,  753,  759,  760,  767,  868,  869,  882,  883,
#         890,  896,  897,  903,  904,  908,  910,  911,  916,  922,  923,
#         925,  931,  932,  939,  945,  946,  952,  953,  954,  959,  960,
#         966,  967, 1024, 1029, 1030, 1036, 1044, 1052, 1053, 1058, 1064,
#        1065, 1071, 1072, 1073, 1078, 1079, 1092, 1093, 1100, 1113, 1114,
#        1223, 1225, 1240, 1261, 1264, 1267, 1268, 1281, 1282, 1284, 1288,
#        1289, 1295, 1296, 1302, 1303, 1309, 1310, 1311, 1316, 1317, 1320,
#        1323, 1324, 1407, 1414, 1420, 1427, 1428, 1436, 1437, 1438, 1441,
#        1442, 1448, 1449, 1455, 1456, 1463, 1469, 1595, 1602, 1603, 1610,
#        1617, 1630, 1636, 1638, 1643, 1644, 1645, 1648, 1651, 1652, 1658,
#        1659, 1664, 1665, 1672, 1673, 1679, 1680, 1684, 1686, 1771, 1777,
#        1778, 1785, 1789, 1790, 1791, 1792, 1803, 1805, 1806, 1809, 1812,
#        1813, 1819, 1820, 1826, 1827, 1955, 1956, 1962, 1963, 1969, 1970,
#        1976, 1981, 1983, 1984, 1985, 1986, 1990, 1997, 1998, 2004, 2011,
#        2012, 2015, 2017, 2018, 2019, 2025, 2026, 2086, 2087, 2112, 2113,
#        2117, 2123, 2124, 2131, 2136, 2137, 2138, 2142, 2144, 2145, 2151,
#        2152, 2158, 2159, 2205, 2292, 2299, 2305, 2312, 2319, 2326, 2327,
#        2333, 2340, 2341, 2450, 2456, 2465, 2466, 2470, 2476, 2484, 2485,
#        2492, 2638, 2639, 2646, 2652, 2659, 2660, 2663, 2681, 2685, 2687,
#        2694, 2708, 2709, 2715, 2716, 2717, 2819, 2834, 2836, 2855, 2917,
#        2923, 2924, 2930, 2931, 2937, 2938, 2945, 2948, 2950, 2959, 2972,
#        2973, 2979, 2980, 3103, 3105, 3106, 3126, 3301, 3309, 3315, 3317,
#        3329, 3330, 3332, 3336, 3337, 3338, 3341, 3343, 3344, 3347, 3458,
#        3466, 3472, 3652, 3658, 3665, 3676, 3680, 3681, 3701, 3707, 3708,
#        3714, 3836], dtype=int64)

# %%
#아웃라이어 제거 후 hist
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('./assets/output/visitors.csv')
df['visitor'] = df['visitor'].str.replace(',', '').astype(float)

df['visitor'].drop(outliers).plot(kind='hist',bins=range(0,100001,100))
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np
df = pd.read_csv('./assets/output/부림동_일최고기온.csv')
df['highest temperature_min'].describe()
# Out:
# count    4012.000000
# mean       15.671747
# std        11.189832
# min       -10.000000
# 25%         6.000000
# 50%        17.000000
# 75%        26.000000
# max        38.000000
# Name: highest temperature_min, dtype: float64

# %%
#히스토그램
#부림동_최고기온
import numpy as np
df = pd.read_csv('./assets/output/부림동_일최고기온.csv')
df['highest temperature_max'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#히스토그램
#부림동_최저기온
df = pd.read_csv('./assets/output/부림동_일최저기온.csv')
df['lowest temperature_min'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#----------6시간 강수량---------
df = pd.read_csv('./assets/output/부림동_6시간강수량.csv')
df['rainfall_min'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['rainfall_max'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['rainfall_mean'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['rainfall_median'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#-----------부림동_강수확률--------
df = pd.read_csv('./assets/output/부림동_강수확률.csv')

df['probability of precipitation_min'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['probability of precipitation_max'].plot(kind='hist')

# %%
df['probability of precipitation_mean'].plot(kind='hist')

# %%
df['probability of precipitation_median'].plot(kind='hist')

# %%
#------------부림동_습도----------
df = pd.read_csv('./assets/output/부림동_습도.csv')
df['humidity_min'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['humidity_max'].plot(kind='hist')

# %%
df['humidity_mean'].plot(kind='hist')

# %%
df['humidity_median'].plot(kind='hist')

# %%
#--------------부림동_풍속
df = pd.read_csv('./assets/output/부림동_풍속.csv')

df['wind speed_max'].describe()
# Out:
# count    3630.000000
# mean        2.025523
# std         1.021140
# min         0.500000
# 25%         1.400000
# 50%         2.000000
# 75%         2.400000
# max        18.799999
# Name: wind speed_median, dtype: float64

# %%
df['wind speed_min'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['wind speed_max'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['wind speed_mean'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['wind speed_median'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./assets/output/dirtydataResult.csv')
df = df.dropna()
def findOutlier(feat):
    
    fig = plt.figure()  # 그래프 크기 설정
    subPlot = fig.add_subplot(1,2,1)
    subPlot.hist(df[feat].values, bins=10)  # 히스토그램 그리기
    subPlot.set_xlabel("Value")  # x축 레이블 설정
    subPlot.set_ylabel("Frequency")  # y축 레이블 설정
    fig.suptitle(f"Histogram of {feat}")  # 그래프 제목 설정
    subPlot2 = fig.add_subplot(1,2,2)
    subPlot2.boxplot(df[feat].values.astype('float'))  # 박스 플롯 그리기
    plt.show()  # 그래프 출력)

for col in df.columns:
    if(col == 'date'):
        continue
    if(col == 'visitor'):
        continue
    findOutlier(col)
